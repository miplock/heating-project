# %% [markdown]
# - ogarnąć temat tych dwóch rozwiązań (powiązane: czy u tylko rośnie? (w sczegolnosci: czy niemaleje na powierzchni kaloryfera?))
# - rozpisz wgl jak wygląda schemat rozwiązania

# %% [markdown]
# - ogarnąć warunek brzegowy robin (później)
