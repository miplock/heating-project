# %% [markdown]
# - ogarnąć temat tych dwóch rozwiązań (powiązane: czy u tylko rośnie? (w sczegolnosci: czy niemaleje na powierzchni kaloryfera?))
# - rozpisz wgl jak wygląda schemat rozwiązania

# %% [markdown]
# - ogarnąć warunek brzegowy robin (później)

# %% [markdown]
# na tym etapie programistycznie moge ogarnac funkcję która bierze aktualny rozklad temperatur w pokoju i sprawdza czy jest juz srednia temperatura osiagnieta oraz funkcje ktora sprawdza czy x,y jest na obszarze kaloryfera

# %% [markdown]
# ## minimal przykład by zrozumieć te dwa rozwiązania (prompt)

# %% [markdown]
# Mamy równanie ciepła na prostej:
# $$
# \frac{d}{dt}u = \frac{d^2}{dx^2}u + u \cdot \textbf{1}(\int_{[a,b]} u(x,t)dx<M)
# $$
# i chcemy to rozwiązać numerycznie przez niejawny schemat Eulera z metodą jakichś tam różnic. $\textbf{1}(\int_{[a,b]} u(x,t)dx<M)$ to funkcja indykatorowa. Jak to zrobić?

# %% [markdown]
# dobra, chyba to zrobię indykatorowo. ale ogolnie teraz chyba pozostaje jeszcze ogarniecie warunkow brzegowych i zdefiniowanie macierzy

# %% [markdown]
# nie teoretyczne a praktyczne: zrobic macierz D1 i D2 jak w notebooku tym:

# %% [markdown]
# https://colab.research.google.com/drive/1ysW9nvnodfFNPiPla_Fo5w5Yysbhxzol?usp=sharing#scrollTo=wsxB1jHLSDCP
