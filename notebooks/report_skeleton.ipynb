# %% [markdown]
# # Raport – Projekt z równania ciepła
#
# **Tytuł:** [wstaw tytuł projektu]
#
# **Autorzy:** [imię nazwisko]

# %% [markdown]
# ## Streszczenie
# - [krótkie podsumowanie celu i wyników]

# %% [markdown]
# ## 1. Opis praktyczny eksperymentów
# - Pytania badawcze (min. 2)
# - Intuicje i oczekiwane wyniki
# - Schematy układów pomieszczeń (rysunki)
# - Tabela stałych fizycznych (nazwa, wartość, źródło)
# - Temperatura zewnętrzna dla każdego eksperymentu
# - Co mierzymy i dlaczego (np. średnia temp., odchylenie std, energia)

# %% [markdown]
# ## 2. Opis matematyczny
# - Równanie ciepła z członem grzania: $\partial_t u = \alpha \Delta u + f$
# - Warunki brzegowe i początkowe
# - Dyskretyzacja (metoda różnic skończonych)
# - Metoda rozwiązania układu dyskretnego

# %% [markdown]
# ## 3. Analiza błędu numerycznego
# - Wybrana metryka błędu / indykator
# - Wykresy błędu vs $h_x$, $h_t$
# - Uzasadnienie wyboru kroków $h_x$, $h_t$

# %% [markdown]
# ## 4. Wyniki eksperymentów
# - Wyniki eksperymentu 1
#   - Wykresy, animacje
#   - Interpretacja
# - Wyniki eksperymentu 2
#   - Wykresy, animacje
#   - Interpretacja
# - (opcjonalnie) Wyniki eksperymentu 3

# %% [markdown]
# ## 5. Podsumowanie i wnioski
# - Tabela podsumowująca
# - Najważniejsze wnioski
# - Ograniczenia modelu

# %% [markdown]
# ## 6. Dodatki
# - Link do repozytorium
# - Informacja o użyciu AI (jeśli dotyczy)
# - Parametry symulacji (siatka, czas, moc grzejników)
